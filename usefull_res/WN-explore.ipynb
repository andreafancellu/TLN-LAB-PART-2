# %% [markdown]
# ### Libreria wordnet in nltk

# %%
import nltk
from nltk.corpus import wordnet as wn

# %%
def get_hyponyms(synset):
    hyponyms = set()
    for hyponym in synset.hyponyms():
        hyponyms |= set(get_hyponyms(hyponym))
    return hyponyms | set(synset.hyponyms())

# %% [markdown]
# ### i synset associati a un termine, e rispettivi iponimi e iperonimi

# %%
# term = 'board'
term = 'bank'
print('\nExploring senses for term "{}"\n'.format(term))

for ss in wn.synsets(term):
    print('\n' + str(ss))
    print(ss.name(), ss.lemma_names()) 
    offset = str(ss.offset()).zfill(8) + '-' + ss.pos()
    print(f'offset: {offset}\n')
    print('def : ' + ss.definition())
    print('ex  : ' + str(ss.examples()))

    print('\n\t ** Hyponyms **')
    for hyp in ss.hyponyms():
        print('\thypon: ' + str(hyp))

    print('\n\t ** Hypernyms **')
    for hyp in ss.hypernyms():
        print('\thyper: ' + str(hyp))
    print()
# Out:
# Exploring senses for term "bank"
#
#
# Synset('bank.n.01')
# bank.n.01 ['bank']
# offset: 09213565-n
#
# def : sloping land (especially the slope beside a body of water)
# ex  : ['they pulled the canoe up on the bank', 'he sat on the bank of the river and watched the currents']
#
# 	 ** Hyponyms **
# 	hypon: Synset('riverbank.n.01')
# 	hypon: Synset('waterside.n.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('slope.n.01')
#
#
# Synset('depository_financial_institution.n.01')
# depository_financial_institution.n.01 ['depository_financial_institution', 'bank', 'banking_concern', 'banking_company']
# offset: 08420278-n
#
# def : a financial institution that accepts deposits and channels the money into lending activities
# ex  : ['he cashed a check at the bank', 'that bank holds the mortgage on my home']
#
# 	 ** Hyponyms **
# 	hypon: Synset('acquirer.n.02')
# 	hypon: Synset('agent_bank.n.02')
# 	hypon: Synset('commercial_bank.n.01')
# 	hypon: Synset('credit_union.n.01')
# 	hypon: Synset('federal_reserve_bank.n.01')
# 	hypon: Synset('home_loan_bank.n.01')
# 	hypon: Synset('lead_bank.n.01')
# 	hypon: Synset('member_bank.n.01')
# 	hypon: Synset('merchant_bank.n.01')
# 	hypon: Synset('state_bank.n.01')
# 	hypon: Synset('thrift_institution.n.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('financial_institution.n.01')
#
#
# Synset('bank.n.03')
# bank.n.03 ['bank']
# offset: 09213434-n
#
# def : a long ridge or pile
# ex  : ['a huge bank of earth']
#
# 	 ** Hyponyms **
# 	hypon: Synset('bluff.n.01')
# 	hypon: Synset('sandbank.n.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('ridge.n.01')
#
#
# Synset('bank.n.04')
# bank.n.04 ['bank']
# offset: 08462066-n
#
# def : an arrangement of similar objects in a row or in tiers
# ex  : ['he operated a bank of switches']
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('array.n.01')
#
#
# Synset('bank.n.05')
# bank.n.05 ['bank']
# offset: 13368318-n
#
# def : a supply or stock held in reserve for future use (especially in emergencies)
# ex  : []
#
# 	 ** Hyponyms **
# 	hypon: Synset('blood_bank.n.01')
# 	hypon: Synset('eye_bank.n.01')
# 	hypon: Synset('food_bank.n.01')
# 	hypon: Synset('soil_bank.n.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('reserve.n.02')
#
#
# Synset('bank.n.06')
# bank.n.06 ['bank']
# offset: 13356402-n
#
# def : the funds held by a gambling house or the dealer in some gambling games
# ex  : ['he tried to break the bank at Monte Carlo']
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('funds.n.01')
#
#
# Synset('bank.n.07')
# bank.n.07 ['bank', 'cant', 'camber']
# offset: 09213828-n
#
# def : a slope in the turn of a road or track; the outside is higher than the inside in order to reduce the effects of centrifugal force
# ex  : []
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('slope.n.01')
#
#
# Synset('savings_bank.n.02')
# savings_bank.n.02 ['savings_bank', 'coin_bank', 'money_box', 'bank']
# offset: 04139859-n
#
# def : a container (usually with a slot in the top) for keeping money at home
# ex  : ['the coin bank was empty']
#
# 	 ** Hyponyms **
# 	hypon: Synset('piggy_bank.n.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('container.n.01')
#
#
# Synset('bank.n.09')
# bank.n.09 ['bank', 'bank_building']
# offset: 02787772-n
#
# def : a building in which the business of banking transacted
# ex  : ['the bank is on the corner of Nassau and Witherspoon']
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('depository.n.01')
#
#
# Synset('bank.n.10')
# bank.n.10 ['bank']
# offset: 00169305-n
#
# def : a flight maneuver; aircraft tips laterally about its longitudinal axis (especially in turning)
# ex  : ['the plane went into a steep bank']
#
# 	 ** Hyponyms **
# 	hypon: Synset('vertical_bank.n.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('flight_maneuver.n.01')
#
#
# Synset('bank.v.01')
# bank.v.01 ['bank']
# offset: 02039413-v
#
# def : tip laterally
# ex  : ['the pilot had to bank the aircraft']
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('tip.v.01')
#
#
# Synset('bank.v.02')
# bank.v.02 ['bank']
# offset: 01587705-v
#
# def : enclose with a bank
# ex  : ['bank roads']
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('enclose.v.03')
#
#
# Synset('bank.v.03')
# bank.v.03 ['bank']
# offset: 02343374-v
#
# def : do business with a bank or keep an account at a bank
# ex  : ['Where do you bank in this town?']
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('transact.v.01')
#
#
# Synset('bank.v.04')
# bank.v.04 ['bank']
# offset: 02343252-v
#
# def : act as the banker in a game or in gambling
# ex  : []
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('act.v.04')
#
#
# Synset('bank.v.05')
# bank.v.05 ['bank']
# offset: 02343056-v
#
# def : be in the banking business
# ex  : []
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('work.v.02')
#
#
# Synset('deposit.v.02')
# deposit.v.02 ['deposit', 'bank']
# offset: 02310855-v
#
# def : put into a bank account
# ex  : ['She deposits her paycheck every month']
#
# 	 ** Hyponyms **
# 	hypon: Synset('redeposit.v.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('give.v.03')
#
#
# Synset('bank.v.07')
# bank.v.07 ['bank']
# offset: 01234793-v
#
# def : cover with ashes so to control the rate of burning
# ex  : ['bank a fire']
#
# 	 ** Hyponyms **
#
# 	 ** Hypernyms **
# 	hyper: Synset('cover.v.01')
#
#
# Synset('trust.v.01')
# trust.v.01 ['trust', 'swear', 'rely', 'bank']
# offset: 00688377-v
#
# def : have confidence or faith in
# ex  : ['We can trust in God', 'Rely on your friends', 'bank on your good education', "I swear by my grandmother's recipes"]
#
# 	 ** Hyponyms **
# 	hypon: Synset('count.v.08')
# 	hypon: Synset('credit.v.04')
# 	hypon: Synset('lean.v.04')
#
# 	 ** Hypernyms **
# 	hyper: Synset('believe.v.01')

# %%
syns = list(wn.all_synsets())
offsets_list = [(s.offset(), s) for s in syns]

print(syns[1:10])
print(offsets_list[1:10])
# Out:
# [Synset('unable.a.01'), Synset('abaxial.a.01'), Synset('adaxial.a.01'), Synset('acroscopic.a.01'), Synset('basiscopic.a.01'), Synset('abducent.a.01'), Synset('adducent.a.01'), Synset('nascent.a.01'), Synset('emergent.s.02')]
# [(2098, Synset('unable.a.01')), (2312, Synset('abaxial.a.01')), (2527, Synset('adaxial.a.01')), (2730, Synset('acroscopic.a.01')), (2843, Synset('basiscopic.a.01')), (2956, Synset('abducent.a.01')), (3131, Synset('adducent.a.01')), (3356, Synset('nascent.a.01')), (3553, Synset('emergent.s.02'))]

# %%
# filtro nouns o verbs a partire da offset
# offset ha forma: 09213565-n
get_n = 'n'
get_v = 'v'

print('term currently investigated is ' + term)

print('--- VERBS ---')
for ss in wn.synsets(term):
    offset = str(ss.offset()).zfill(8) + '-' + ss.pos()
    if offset[-1] == get_v:
        print(offset)

print('--- NOUNS ---')        
for ss in wn.synsets(term):
    offset = str(ss.offset()).zfill(8) + '-' + ss.pos()
    if offset[-1] == get_n:
        print(offset)
# Out:
# term currently investigated is bank
# --- VERBS ---
# 02039413-v
# 01587705-v
# 02343374-v
# 02343252-v
# 02343056-v
# 02310855-v
# 01234793-v
# 00688377-v
# --- NOUNS ---
# 09213565-n
# 08420278-n
# 09213434-n
# 08462066-n
# 13368318-n
# 13356402-n
# 09213828-n
# 04139859-n
# 02787772-n
# 00169305-n

# %% [markdown]
# ### iperonimi di un dato synset

# %%
wn.synset('pasta.n.01').hyponyms()

for hyp in get_hyponyms(wn.synset('pasta.n.01')):
    print(hyp)

# IPERONIMI
term = 'pasta'
for ss in wn.synsets(term):
    print('\n\t ** Hypernyms **')
    for hyp in ss.hypernyms():
        print('\thyper: ' + str(hyp))
# Out:
# Synset('lasagna.n.01')
# Synset('macaroni_and_cheese.n.01')
# Synset('cannelloni.n.01')
# Synset('spaghetti.n.01')
#
# 	 ** Hypernyms **
# 	hyper: Synset('dish.n.02')
#
# 	 ** Hypernyms **
# 	hyper: Synset('food.n.02')

# %% [markdown]
# ### parti e componenti

# %%
print(wn.synset('car.n.01'), wn.synset('car.n.01').definition())
print(wn.synset('car.n.01').part_meronyms())
# Out:
# Synset('car.n.01') a motor vehicle with four wheels; usually propelled by an internal combustion engine
# [Synset('accelerator.n.01'), Synset('air_bag.n.01'), Synset('auto_accessory.n.01'), Synset('automobile_engine.n.01'), Synset('automobile_horn.n.01'), Synset('buffer.n.06'), Synset('bumper.n.02'), Synset('car_door.n.01'), Synset('car_mirror.n.01'), Synset('car_seat.n.01'), Synset('car_window.n.01'), Synset('fender.n.01'), Synset('first_gear.n.01'), Synset('floorboard.n.02'), Synset('gasoline_engine.n.01'), Synset('glove_compartment.n.01'), Synset('grille.n.02'), Synset('high_gear.n.01'), Synset('hood.n.09'), Synset('luggage_compartment.n.01'), Synset('rear_window.n.01'), Synset('reverse.n.02'), Synset('roof.n.02'), Synset('running_board.n.01'), Synset('stabilizer_bar.n.01'), Synset('sunroof.n.01'), Synset('tail_fin.n.02'), Synset('third_gear.n.01'), Synset('window.n.02')]

# %% [markdown]
# ### sense similarity

# %%
s1 = wn.synset('dog.n.01')
s2 = wn.synset('cat.n.01')

print('[S1: {}] {}\n'.format(s1, s1.definition()))
print('[S1: {}] {}\n'.format(s2, s2.definition()))

print('wup_similarity({}, {}) = {}'.format(s1, s2, s1.wup_similarity(s2)))
print('lch_similarity({}, {}) = {}'.format(s1, s2, s1.lch_similarity(s2)))
print('path_similarity({}, {}) = {}'.format(s1, s2, s1.path_similarity(s2)))

# NB: wup_similarity è la Wu & Palmer similarity, che dobbiamo reimplementare

# for ss1 in wn.synsets('dog'):
#     for ss2 in wn.synsets('cat'):
#         print('sim ' + str(ss1) + ', ' + str(ss2) + ' = ' + str(ss1.wup_similarity(ss2)))
# Out:
# [S1: Synset('dog.n.01')] a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds
#
# [S1: Synset('cat.n.01')] feline mammal usually having thick soft fur and no ability to roar: domestic cats; wildcats
#
# wup_similarity(Synset('dog.n.01'), Synset('cat.n.01')) = 0.8571428571428571
# lch_similarity(Synset('dog.n.01'), Synset('cat.n.01')) = 2.0281482472922856
# path_similarity(Synset('dog.n.01'), Synset('cat.n.01')) = 0.2

# %% [markdown]
# ### verbi e entailment (implicazione)

# %%
print('Exploring entailment relation in verbs')
verb = 'snore' # RUSSARE...
count = 1
# NB: con il secondo parametro selezioniamo il PoS, in questo caso VB
for ss in wn.synsets(verb, 'v'):
    print('sense {}({}): to {} implies to {}'.format(count, ss, verb, ss.entailments()))
    count+=1
# Out:
# Exploring entailment relation in verbs
# sense 1(Synset('snore.v.01')): to snore implies to [Synset('sleep.v.01')]

# %% [markdown]
# #### esploro come funzionano i nomi composti (pick up)

# %%
term = 'add_on'
# term = 'give_up'
print('\nExploring senses for term "{}"\n'.format(term))

for ss in wn.synsets(term):
    print('\n' + str(ss))
    print(ss.name(), ss.lemma_names()) 
    print('def : ' + ss.definition())
    print('ex  : ' + str(ss.examples()))

#     print('\n\t ** Hyponyms **')
#     for hyp in ss.hyponyms():
#         print('\thypon: ' + str(hyp))

#     print('\n\t ** Hypernyms **')
#     for hyp in ss.hypernyms():
#         print('\thyper: ' + str(hyp))
    print()
# Out:
# Exploring senses for term "give_up"
#
#
# Synset('forfeit.v.01')
# forfeit.v.01 ['forfeit', 'give_up', 'throw_overboard', 'waive', 'forgo', 'forego']
# def : lose (s.th.) or lose the right to (s.th.) by some error, offense, or crime
# ex  : ["you've forfeited your right to name your successor", 'forfeited property']
#
#
# Synset('abandon.v.02')
# abandon.v.02 ['abandon', 'give_up']
# def : give up with the intent of never claiming again
# ex  : ['Abandon your life to God', 'She gave up her children to her ex-husband when she moved to Tahiti', 'We gave the drowning victim up for dead']
#
#
# Synset('drop_out.v.01')
# drop_out.v.01 ['drop_out', 'give_up', 'fall_by_the_wayside', 'drop_by_the_wayside', 'throw_in', 'throw_in_the_towel', 'quit', 'chuck_up_the_sponge']
# def : give up in the face of defeat of lacking hope; admit defeat
# ex  : ['In the second round, the challenger gave up']
#
#
# Synset('discontinue.v.01')
# discontinue.v.01 ['discontinue', 'stop', 'cease', 'give_up', 'quit', 'lay_off']
# def : put an end to a state or an activity
# ex  : ['Quit teasing your little brother']
#
#
# Synset('spare.v.03')
# spare.v.03 ['spare', 'give_up', 'part_with', 'dispense_with']
# def : give up what is not strictly needed
# ex  : ['he asked if they could spare one of their horses to speed his journey']
#
#
# Synset('release.v.08')
# release.v.08 ['release', 'relinquish', 'resign', 'free', 'give_up']
# def : part with a possession or right
# ex  : ['I am relinquishing my bedroom to the long-term house guest', 'resign a claim to the throne']
#
#
# Synset('vacate.v.01')
# vacate.v.01 ['vacate', 'resign', 'renounce', 'give_up']
# def : leave (a job, post, or position) voluntarily
# ex  : ['She vacated the position when she got pregnant', 'The chairman resigned when he was found to have misappropriated funds']
#
#
# Synset('surrender.v.02')
# surrender.v.02 ['surrender', 'cede', 'deliver', 'give_up']
# def : relinquish possession or control over
# ex  : ['The squatters had to surrender the building after the police moved in']
#
#
# Synset('surrender.v.01')
# surrender.v.01 ['surrender', 'give_up']
# def : give up or agree to forgo to the power or possession of another
# ex  : ['The last Taleban fighters finally surrendered']
#
#
# Synset('abandon.v.04')
# abandon.v.04 ['abandon', 'give_up']
# def : stop maintaining or insisting on; of ideas or claims
# ex  : ['He abandoned the thought of asking for her hand in marriage', 'Both sides have to give up some claims in these negotiations']
#
#
# Synset('give_up.v.11')
# give_up.v.11 ['give_up', 'allow']
# def : allow the other (baseball) team to score
# ex  : ['give up a run']
#
#
# Synset('kick.v.06')
# kick.v.06 ['kick', 'give_up']
# def : stop consuming
# ex  : ['kick a habit', 'give up alcohol']
