# %% [markdown]
# # Es.1 - Conceptual Similarity

# %% [markdown]
# In questo esercizio andiamo ad esplorare varie tecniche per calcolare la similarità semantica tra
# due parole. Per farlo utilizzeremo il dataset WordSim353.csv, che contiene una serie di coppie di
#  parole e il loro punteggio di similarità. Il punteggio è un valore reale compreso tra 0 e 10.
#
# Le misure di similarità che utilizzeremo sono:
#
# - Wu and Palmer
# - Shortest Path
# - Leakcock & Chodorow

# %% [markdown]
# ### Imports

# %%
from nltk.corpus import stopwords
from collections import Counter
from gensim.test.utils import simple_preprocess
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
import random

# %% [markdown]
# ### Data preparation

# %%
def get_text_from_file(path):
    '''
    Read a file and, after revoving all stopwords, return a list of words.
    '''
    file = []
    stop_words = set(stopwords.words('english'))
    with open (path, 'r') as f:
        for row in f:
            filtered_s = [w for w in word_tokenize(row) if not w.lower() in stop_words]
            file.append(simple_preprocess(str(filtered_s), deacc=True))
    f.close()
    return file

def extract_triple(path):
    '''
    Read a file and return the first 2 word in each row, as a tuple.
    '''
    tuple_list = []
    with open (path, 'r') as f:
        for row in f:
            # Remove \n
            row = row.strip()
            # Organize in a triple the values
            tuple_list.append(tuple(row.split(",")[:3]))
            
        # Remove first value of the tuple
        tuple_list.pop(0)
    f.close()
    return tuple_list

# %%
values = extract_triple('../data/WordSim353.csv')

# %% [markdown]
# ### Wu and Palmer

# %%
def get_synsets(term):
    '''
    Retrurn the synsets of a term.
    '''
    if(len(wn.synsets(term)) > 0):
        return wn.synsets(term)
    return None

def depth(syn):
    '''
    Return the distance between the WorNet root and a synset.
    '''
    if(syn is None):
        return 0
    if(type(syn) is list):
        if(len(syn) > 0):
            return syn[0].max_depth()
        return 0
    return syn.max_depth()

def lch(syn1, syn2):
    '''
    Return the lowest common hypenyms of two synsets.
    '''
    if(syn1 is None or syn2 is None):
        return None
    return syn1.lowest_common_hypernyms(syn2)

def wu_pal_sim(syn1, syn2):
    '''
    Return the Wu-Palmer similarity of two synsets.
    '''
    if(syn1 is None or syn2 is None):
        return 0
    return syn1.wup_similarity(syn2)

def my_wu_pal_sim(syn1, syn2):
    if(syn1 is None or syn2 is None):
        return None
    else:
        if(depth(syn1) + depth(syn2) == 0):
            return 0
        return 2.0 * depth(lch(syn1, syn2)) / (depth(syn1) + depth(syn2))
    
def max_similarity(syns1, syns2):
    sim_max = ("", "", 0)
    
    for syn1 in syns1:
        for syn2 in syns2:
            if(syns1 is not None and syns2 is not None):
                sim = my_wu_pal_sim(syn1, syn2)
                if sim > sim_max[2]:
                    sim_max = (syn1, syn2, sim)
                    
    return sim_max

# %%
for val in values:
    syns1 = get_synsets(val[0])
    syns2 = get_synsets(val[1])
        
    sim = max_similarity(syns1, syns2)

    print("\n", sim)
# Out:
#  (Synset('sexual_love.n.02'), Synset('sexual_activity.n.01'), 0.9090909090909091)
#
#  (Synset('tiger.n.02'), Synset('big_cat.n.01'), 0.9629629629629629)
#
#  (Synset('tiger.n.01'), Synset('tiger.n.01'), 1.0)
#
#  (Synset('book.n.02'), Synset('newspaper.n.03'), 0.8571428571428571)
#
#  (Synset('computer.n.01'), Synset('keyboard.n.01'), 0.8)
#
#  (Synset('computer.n.01'), Synset('internet.n.01'), 0.5882352941176471)
#
#  (Synset('airplane.n.01'), Synset('car.n.02'), 0.7)
#
#  (Synset('train.n.01'), Synset('car.n.02'), 0.7058823529411765)
#
#  ('', '', 0)
#
#  (Synset('television_receiver.n.01'), Synset('radio_receiver.n.01'), 0.9)
#
#  (Synset('medium.n.01'), Synset('radio.n.01'), 0.8)
#
#  ('', '', 0)
#
#  (Synset('bread.n.01'), Synset('butter.n.01'), 0.7142857142857143)
#
#  (Synset('cucumber.n.01'), Synset('potato.n.02'), 0.8)
#
#  (Synset('doctor.n.01'), Synset('nurse.n.01'), 0.8571428571428571)
#
#  (Synset('professor.n.01'), Synset('doctor.n.01'), 0.7272727272727273)
#
#  (Synset('student.n.01'), Synset('professor.n.01'), 0.631578947368421)
#
#  ('', '', 0)
#
#  ('', '', 0)
#
#  (Synset('company.n.04'), Synset('lineage.n.01'), 0.5454545454545454)
#
#  (Synset('stock.n.02'), Synset('marketplace.n.02'), 0.5)
#
#  (Synset('stock.n.03'), Synset('earphone.n.01'), 0.6666666666666666)
#
#  (Synset('stock.n.03'), Synset('compact_disk.n.01'), 0.7058823529411765)
#
#  (Synset('livestock.n.01'), Synset('jaguar.n.01'), 0.8)
#
#  (Synset('broth.n.01'), Synset('egg.n.02'), 0.5714285714285714)
#
#  ('', '', 0)
#
#  ('', '', 0)
#
#  (Synset('stock.n.12'), Synset('life.n.08'), 0.5555555555555556)
#
#  (Synset('book.n.06'), Synset('library.n.02'), 0.75)
#
#  (Synset('bank.n.06'), Synset('money.n.02'), 0.5)
#
#  (Synset('forest.n.01'), Synset('forest.n.01'), 1.0)
#
#  (Synset('money.n.03'), Synset('cash.n.01'), 0.8571428571428571)
#
#  (Synset('professor.n.01'), Synset('cucumber.n.01'), 0.45454545454545453)
#
#  (Synset('king.n.02'), Synset('cabbage.n.03'), 0.5263157894736842)
#
#  (Synset('king.n.02'), Synset('king.n.02'), 1.0)
#
#  (Synset('king.n.10'), Synset('castle.n.03'), 0.9)
#
#  (Synset('bishop.n.01'), Synset('rabbi.n.01'), 0.8)
#
#  (Synset('jerusalem.n.01'), Synset('israel.n.01'), 0.6666666666666666)
#
#  (Synset('jerusalem.n.01'), Synset('palestinian.n.01'), 0.2)
#
#  (Synset('holy_place.n.01'), Synset('sexual_activity.n.01'), 0.18181818181818182)
#
#  (Synset('fuck.n.01'), Synset('sexual_activity.n.01'), 0.8333333333333334)
#
#  (Synset('football.n.01'), Synset('soccer.n.01'), 0.9565217391304348)
#
#  (Synset('football.n.02'), Synset('basketball.n.02'), 0.8888888888888888)
#
#  (Synset('football.n.01'), Synset('tennis.n.01'), 0.7619047619047619)
#
#  (Synset('tennis.n.01'), Synset('racket.n.02'), 0.5263157894736842)
#
#  ('', '', 0)
#
#  (Synset('arafat.n.01'), Synset('terror.n.02'), 0.7058823529411765)
#
#  (Synset('arafat.n.01'), Synset('jackson.n.04'), 0.8)
#
#  ('', '', 0)
#
#  (Synset('movie.n.01'), Synset('star.n.01'), 0.46153846153846156)
#
#  (Synset('movie.n.01'), Synset('popcorn.n.01'), 0.3)
#
#  (Synset('movie.n.01'), Synset('critic.n.01'), 0.375)
#
#  (Synset('movie.n.01'), Synset('theater.n.01'), 0.5714285714285714)
#
#  (Synset('purgative.n.01'), Synset('proton.n.01'), 0.1111111111111111)
#
#  (Synset('physics.n.01'), Synset('chemistry.n.01'), 0.8888888888888888)
#
#  (Synset('space.n.01'), Synset('chemistry.n.03'), 0.2857142857142857)
#
#  (Synset('alcohol.n.02'), Synset('chemistry.n.02'), 0.6666666666666666)
#
#  (Synset('vodka.n.01'), Synset('gin.n.01'), 0.9)
#
#  (Synset('vodka.n.01'), Synset('brandy.n.01'), 0.9)
#
#  (Synset('drink.n.04'), Synset('car.n.02'), 0.15384615384615385)
#
#  (Synset('drink.n.04'), Synset('ear.n.01'), 0.36363636363636365)
#
#  (Synset('drink.n.02'), Synset('sass.n.01'), 0.4444444444444444)
#
#  ('', '', 0)
#
#  (Synset('baby.n.05'), Synset('mother.n.03'), 0.8)
#
#  (Synset('beverage.n.01'), Synset('mother.n.02'), 0.46153846153846156)
#
#  (Synset('car.n.01'), Synset('car.n.01'), 1.0)
#
#  (Synset('jewel.n.02'), Synset('jewel.n.02'), 1.0)
#
#  (Synset('journey.n.01'), Synset('voyage.n.02'), 0.9473684210526315)
#
#  (Synset('male_child.n.01'), Synset('cub.n.02'), 0.9411764705882353)
#
#  (Synset('seashore.n.01'), Synset('shore.n.01'), 0.8888888888888888)
#
#  (Synset('mental_hospital.n.01'), Synset('bedlam.n.02'), 0.9473684210526315)
#
#  (Synset('sorcerer.n.01'), Synset('sorcerer.n.01'), 1.0)
#
#  (Synset('noon.n.01'), Synset('noon.n.01'), 1.0)
#
#  (Synset('furnace.n.01'), Synset('stove.n.02'), 0.47058823529411764)
#
#  (Synset('food.n.03'), Synset('fruit.n.03'), 0.3076923076923077)
#
#  (Synset('bird.n.01'), Synset('cock.n.05'), 0.9473684210526315)
#
#  (Synset('bird.n.01'), Synset('crane.n.05'), 0.8571428571428571)
#
#  (Synset('tool.n.01'), Synset('implement.n.01'), 0.9230769230769231)
#
#  (Synset('brother.n.05'), Synset('monk.n.01'), 0.9473684210526315)
#
#  (Synset('crane.n.04'), Synset('implement.n.01'), 0.7142857142857143)
#
#  (Synset('chap.n.01'), Synset('buddy.n.01'), 0.75)
#
#  ('', '', 0)
#
#  (Synset('monk.n.01'), Synset('prophet.n.01'), 0.631578947368421)
#
#  (Synset('cemetery.n.01'), Synset('forest.n.02'), 0.3076923076923077)
#
#  (Synset('food.n.01'), Synset('cock.n.04'), 0.11764705882352941)
#
#  (Synset('seashore.n.01'), Synset('hill.n.01'), 0.6)
#
#  (Synset('forest.n.02'), Synset('cemetery.n.01'), 0.3076923076923077)
#
#  (Synset('shore.n.01'), Synset('forest.n.02'), 0.4444444444444444)
#
#  (Synset('monk.n.01'), Synset('slave.n.01'), 0.75)
#
#  (Synset('seashore.n.01'), Synset('forest.n.02'), 0.4)
#
#  (Synset('chap.n.01'), Synset('ace.n.03'), 0.75)
#
#  (Synset('chord.n.02'), Synset('smile.n.01'), 0.2857142857142857)
#
#  (Synset('glass.n.02'), Synset('sorcerer.n.01'), 0.4)
#
#  (Synset('noon.n.01'), Synset('string.n.09'), 0.15384615384615385)
#
#  ('', '', 0)
#
#  (Synset('money.n.03'), Synset('dollar.n.02'), 0.75)
#
#  (Synset('money.n.03'), Synset('cash.n.01'), 0.8571428571428571)
#
#  (Synset('money.n.03'), Synset('currency.n.01'), 0.9230769230769231)
#
#  (Synset('money.n.02'), Synset('wealth.n.04'), 0.9090909090909091)
#
#  (Synset('money.n.02'), Synset('property.n.01'), 0.8)
#
#  (Synset('money.n.02'), Synset('possession.n.02'), 0.6666666666666666)
#
#  (Synset('money.n.02'), Synset('bank.n.06'), 0.5)
#
#  (Synset('money.n.01'), Synset('deposit.n.04'), 0.8571428571428571)
#
#  (Synset('money.n.01'), Synset('withdrawal.n.03'), 0.16666666666666666)
#
#  (Synset('money.n.01'), Synset('laundering.n.01'), 0.14285714285714285)
#
#  (Synset('money.n.01'), Synset('process.n.02'), 0.2)
#
#  (Synset('tiger.n.02'), Synset('jaguar.n.01'), 0.9285714285714286)
#
#  (Synset('tiger.n.02'), Synset('feline.n.01'), 0.9230769230769231)
#
#  (Synset('tiger.n.02'), Synset('carnivore.n.01'), 0.88)
#
#  (Synset('tiger.n.02'), Synset('mammal.n.01'), 0.782608695652174)
#
#  (Synset('tiger.n.01'), Synset('animal.n.01'), 0.7692307692307693)
#
#  (Synset('tiger.n.01'), Synset('organism.n.01'), 0.8333333333333334)
#
#  (Synset('tiger.n.01'), Synset('animal.n.01'), 0.7692307692307693)
#
#  (Synset('tiger.n.01'), Synset('menagerie.n.02'), 0.46153846153846156)
#
#  (Synset('psychology.n.01'), Synset('psychiatry.n.01'), 0.7)
#
#  (Synset('psychology.n.01'), Synset('anxiety.n.01'), 0.14285714285714285)
#
#  (Synset('psychology.n.01'), Synset('fear.n.01'), 0.14285714285714285)
#
#  (Synset('psychology.n.01'), Synset('depression.n.10'), 0.26666666666666666)
#
#  (Synset('psychology.n.01'), Synset('clinic.n.01'), 0.13333333333333333)
#
#  (Synset('psychology.n.01'), Synset('doctor.n.03'), 0.25)
#
#  ('', '', 0)
#
#  (Synset('psychology.n.01'), Synset('judgment.n.01'), 0.5333333333333333)
#
#  (Synset('psychology.n.01'), Synset('health.n.02'), 0.15384615384615385)
#
#  (Synset('psychology.n.01'), Synset('science.n.01'), 0.9333333333333333)
#
#  (Synset('psychology.n.01'), Synset('discipline.n.01'), 0.8571428571428571)
#
#  (Synset('psychology.n.01'), Synset('cognition.n.01'), 0.5454545454545454)
#
#  (Synset('planet.n.01'), Synset('star.n.01'), 0.8333333333333334)
#
#  (Synset('planet.n.01'), Synset('constellation.n.02'), 0.7272727272727273)
#
#  (Synset('planet.n.01'), Synset('moon.n.01'), 0.7692307692307693)
#
#  (Synset('planet.n.01'), Synset('sun.n.01'), 0.7692307692307693)
#
#  (Synset('satellite.n.02'), Synset('galax.n.01'), 0.5882352941176471)
#
#  (Synset('planet.n.01'), Synset('quad.n.03'), 0.46153846153846156)
#
#  (Synset('satellite.n.02'), Synset('astronomer.n.01'), 0.7058823529411765)
#
#  (Synset('precedent.n.01'), Synset('example.n.01'), 0.9090909090909091)
#
#  (Synset('precedent.n.01'), Synset('information.n.02'), 0.8)
#
#  (Synset('precedent.n.01'), Synset('cognition.n.01'), 0.6666666666666666)
#
#  (Synset('common_law.n.02'), Synset('law.n.01'), 0.8888888888888888)
#
#  (Synset('common_law.n.02'), Synset('collection.n.01'), 0.75)
#
#  (Synset('common_law.n.02'), Synset('group.n.01'), 0.5714285714285714)
#
#  (Synset('precedent.n.04'), Synset('antecedent.n.04'), 0.5454545454545454)
#
#  (Synset('cup.n.06'), Synset('coffee.n.01'), 0.7368421052631579)
#
#  (Synset('cup.n.01'), Synset('tableware.n.01'), 0.875)
#
#  (Synset('cup.n.01'), Synset('article.n.02'), 0.7142857142857143)
#
#  (Synset('cup.n.07'), Synset('artifact.n.01'), 0.7272727272727273)
#
#  (Synset('cup.n.05'), Synset('object.n.01'), 0.4444444444444444)
#
#  ('', '', 0)
#
#  (Synset('cup.n.06'), Synset('beverage.n.01'), 0.7777777777777778)
#
#  (Synset('cup.n.06'), Synset('food.n.01'), 0.5333333333333333)
#
#  (Synset('cup.n.06'), Synset('substance.n.01'), 0.5333333333333333)
#
#  (Synset('cup.n.06'), Synset('liquid.n.01'), 0.7058823529411765)
#
#  (Synset('jaguar.n.01'), Synset('big_cat.n.01'), 0.9629629629629629)
#
#  (Synset('jaguar.n.01'), Synset('car.n.02'), 0.2608695652173913)
#
#  (Synset('energy.n.01'), Synset('secretary.n.01'), 0.13333333333333333)
#
#  ('', '', 0)
#
#  (Synset('energy.n.01'), Synset('testing_ground.n.01'), 0.18181818181818182)
#
#  (Synset('computer.n.01'), Synset('testing_ground.n.01'), 0.3076923076923077)
#
#  (Synset('weapon.n.02'), Synset('secret.n.01'), 0.16666666666666666)
#
#  (Synset('federal_bureau_of_investigation.n.01'), Synset('fingerprint.n.02'), 0.13333333333333333)
#
#  (Synset('federal_bureau_of_investigation.n.01'), Synset('investigation.n.02'), 0.125)
#
#  (Synset('investigation.n.02'), Synset('effort.n.02'), 0.8)
#
#  (Synset('mars.n.01'), Synset('water_system.n.02'), 0.42857142857142855)
#
#  (Synset('mars.n.01'), Synset('scientist.n.01'), 0.4)
#
#  (Synset('news.n.02'), Synset('report.n.03'), 0.9090909090909091)
#
#  (Synset('canyon.n.01'), Synset('landscape.n.03'), 0.26666666666666666)
#
#  (Synset('picture.n.01'), Synset('surface.n.01'), 0.6666666666666666)
#
#  (Synset('discovery.n.01'), Synset('space.n.01'), 0.25)
#
#  (Synset('water.n.03'), Synset('seepage.n.01'), 0.14285714285714285)
#
#  (Synset('signboard.n.01'), Synset('recess.n.04'), 0.7142857142857143)
#
#  (Synset('wednesday.n.01'), Synset('news.n.01'), 0.15384615384615385)
#
#  (Synset('mile.n.01'), Synset('kilometer.n.01'), 0.7692307692307693)
#
#  ('', '', 0)
#
#  (Synset('district.n.01'), Synset('surface.n.03'), 0.5454545454545454)
#
#  (Synset('atmosphere.n.03'), Synset('landscape.n.01'), 0.42857142857142855)
#
#  (Synset('president_of_the_united_states.n.02'), Synset('decoration.n.02'), 0.13333333333333333)
#
#  (Synset('war.n.02'), Synset('military_personnel.n.01'), 0.18181818181818182)
#
#  (Synset('record.n.03'), Synset('number.n.02'), 0.8888888888888888)
#
#  (Synset('skin.n.02'), Synset('eye.n.05'), 0.6153846153846154)
#
#  (Synset('japanese.n.01'), Synset('american.n.01'), 0.8235294117647058)
#
#  (Synset('dramaturgy.n.01'), Synset('history.n.05'), 0.4)
#
#  ('', '', 0)
#
#  (Synset('bias.n.01'), Synset('recognition.n.07'), 0.6153846153846154)
#
#  (Synset('decoration.n.02'), Synset('heroism.n.01'), 0.15384615384615385)
#
#  (Synset('century.n.01'), Synset('year.n.01'), 0.8)
#
#  (Synset('century.n.01'), Synset('nation.n.02'), 0.2222222222222222)
#
#  (Synset('delay.n.02'), Synset('racism.n.02'), 0.5714285714285714)
#
#  (Synset('delay.n.02'), Synset('news_program.n.01'), 0.46153846153846156)
#
#  (Synset('curate.n.01'), Synset('party.n.05'), 0.7058823529411765)
#
#  (Synset('peace.n.01'), Synset('plan.n.01'), 0.18181818181818182)
#
#  (Synset('minority.n.03'), Synset('peace.n.01'), 0.5)
#
#  (Synset('attempt.n.01'), Synset('peace.n.01'), 0.18181818181818182)
#
#  (Synset('government.n.02'), Synset('crisis.n.02'), 0.46153846153846156)
#
#  (Synset('deployment.n.01'), Synset('departure.n.01'), 0.6666666666666666)
#
#  (Synset('deployment.n.01'), Synset('coitus_interruptus.n.01'), 0.75)
#
#  (Synset('energy.n.05'), Synset('crisis.n.01'), 0.5714285714285714)
#
#  (Synset('announcement.n.01'), Synset('news.n.01'), 0.6)
#
#  (Synset('announcement.n.01'), Synset('attempt.n.01'), 0.18181818181818182)
#
#  (Synset('stroke.n.07'), Synset('hospital.n.01'), 0.3333333333333333)
#
#  (Synset('disability.n.01'), Synset('death.n.03'), 0.46153846153846156)
#
#  (Synset('victim.n.02'), Synset('hand_brake.n.01'), 0.375)
#
#  (Synset('discussion.n.01'), Synset('recovery.n.03'), 0.7272727272727273)
#
#  (Synset('diary.n.01'), Synset('association.n.06'), 0.25)
#
#  (Synset('doctor.n.03'), Synset('force.n.04'), 0.15384615384615385)
#
#  (Synset('doctor.n.03'), Synset('indebtedness.n.01'), 0.15384615384615385)
#
#  (Synset('liability.n.01'), Synset('indemnity.n.01'), 0.5714285714285714)
#
#  (Synset('school.n.02'), Synset('center.n.03'), 0.8571428571428571)
#
#  (Synset('rationality.n.01'), Synset('high_blood_pressure.n.01'), 0.5)
#
#  (Synset('reason.n.03'), Synset('criterion.n.02'), 0.46153846153846156)
#
#  (Synset('hundred.n.01'), Synset('percentage.n.01'), 0.14285714285714285)
#
#  (Synset('harvard.n.02'), Synset('yale.n.02'), 0.9090909090909091)
#
#  (Synset('hospital.n.02'), Synset('infrastructure.n.01'), 0.15384615384615385)
#
#  (Synset('death.n.08'), Synset('quarrel.n.01'), 0.4444444444444444)
#
#  (Synset('death.n.02'), Synset('inmate.n.01'), 0.13333333333333333)
#
#  ('', '', 0)
#
#  (Synset('life.n.11'), Synset('death.n.02'), 0.8333333333333334)
#
#  (Synset('life_sentence.n.01'), Synset('term.n.02'), 0.8333333333333334)
#
#  (Synset('son.n.02'), Synset('similarity.n.02'), 0.4)
#
#  (Synset('board.n.01'), Synset('recommendation.n.03'), 0.15384615384615385)
#
#  ('', '', 0)
#
#  (Synset('organization_of_petroleum-exporting_countries.n.01'), Synset('state.n.04'), 0.5)
#
#  (Synset('peace.n.04'), Synset('atmosphere.n.01'), 0.6666666666666666)
#
#  (Synset('peace.n.04'), Synset('indemnity.n.01'), 0.8)
#
#  (Synset('territory.n.02'), Synset('kilometer.n.01'), 0.14285714285714285)
#
#  (Synset('travel.n.01'), Synset('activity.n.01'), 0.6153846153846154)
#
#  (Synset('rival.n.01'), Synset('price.n.07'), 0.6)
#
#  ('', '', 0)
#
#  (Synset('consumer.n.01'), Synset('energy.n.01'), 0.14285714285714285)
#
#  ('', '', 0)
#
#  (Synset('car.n.02'), Synset('flight.n.03'), 0.5)
#
#  (Synset('recognition.n.03'), Synset('calling_card.n.02'), 0.5454545454545454)
#
#  (Synset('recognition.n.03'), Synset('information.n.01'), 0.6666666666666666)
#
#  (Synset('hotel.n.01'), Synset('reservation.n.01'), 0.2857142857142857)
#
#  ('', '', 0)
#
#  (Synset('adjustment.n.03'), Synset('arrangement.n.06'), 0.625)
#
#  (Synset('arrangement.n.06'), Synset('accommodation.n.05'), 0.625)
#
#  ('', '', 0)
#
#  (Synset('type.n.01'), Synset('kind.n.01'), 0.9411764705882353)
#
#  (Synset('arrival.n.03'), Synset('hotel.n.01'), 0.4)
#
#  (Synset('bed.n.01'), Synset('wardrobe.n.01'), 0.8235294117647058)
#
#  (Synset('cupboard.n.01'), Synset('apparel.n.01'), 0.5)
#
#  (Synset('position.n.06'), Synset('decision.n.01'), 0.5714285714285714)
#
#  (Synset('situation.n.01'), Synset('isolation.n.01'), 0.6666666666666666)
#
#  (Synset('impartiality.n.01'), Synset('pastime.n.01'), 0.3076923076923077)
#
#  (Synset('steering.n.02'), Synset('combination.n.06'), 0.625)
#
#  (Synset('street.n.03'), Synset('place.n.13'), 0.5454545454545454)
#
#  (Synset('street.n.01'), Synset('avenue.n.02'), 0.9411764705882353)
#
#  (Synset('street.n.01'), Synset('block.n.01'), 0.6153846153846154)
#
#  (Synset('street.n.01'), Synset('child.n.03'), 0.4)
#
#  (Synset('listing.n.02'), Synset('proximity.n.03'), 0.23529411764705882)
#
#  (Synset('listing.n.02'), Synset('category.n.02'), 0.2857142857142857)
#
#  (Synset('cellular_telephone.n.01'), Synset('telephone.n.01'), 0.8888888888888888)
#
#  (Synset('production.n.01'), Synset('hike.n.01'), 0.5333333333333333)
#
#  (Synset('benchmark.n.01'), Synset('index.n.01'), 0.7272727272727273)
#
#  (Synset('medium.n.03'), Synset('trading.n.01'), 0.5714285714285714)
#
#  (Synset('medium.n.08'), Synset('profit.n.02'), 0.4)
#
#  (Synset('dividend.n.03'), Synset('payment.n.01'), 0.875)
#
#  (Synset('dividend.n.02'), Synset('calculation.n.01'), 0.16666666666666666)
#
#  (Synset('calculation.n.01'), Synset('calculation.n.01'), 1.0)
#
#  (Synset('currency.n.01'), Synset('market.n.02'), 0.18181818181818182)
#
#  (Synset('organization_of_petroleum-exporting_countries.n.01'), Synset('oil.n.02'), 0.1111111111111111)
#
#  (Synset('oil.n.02'), Synset('stock.n.02'), 0.5)
#
#  (Synset('announcement.n.01'), Synset('production.n.02'), 0.4)
#
#  (Synset('announcement.n.01'), Synset('admonition.n.01'), 0.5454545454545454)
#
#  (Synset('profit.n.02'), Synset('admonition.n.01'), 0.16666666666666666)
#
#  (Synset('net_income.n.01'), Synset('loss.n.06'), 0.6666666666666666)
#
#  (Synset('dollar.n.01'), Synset('yen.n.02'), 0.7692307692307693)
#
#  (Synset('dollar.n.02'), Synset('dollar.n.02'), 1.0)
#
#  (Synset('dollar.n.04'), Synset('profit.n.02'), 0.18181818181818182)
#
#  (Synset('dollar.n.04'), Synset('loss.n.01'), 0.2)
#
#  ('', '', 0)
#
#  (Synset('network.n.04'), Synset('hardware.n.02'), 0.7692307692307693)
#
#  (Synset('telephone.n.01'), Synset('equipment.n.01'), 0.8571428571428571)
#
#  (Synset('equipment.n.01'), Synset('maker.n.01'), 0.42857142857142855)
#
#  ('', '', 0)
#
#  (Synset('five.n.01'), Synset('month.n.02'), 0.36363636363636365)
#
#  (Synset('report_card.n.01'), Synset('addition.n.03'), 0.2222222222222222)
#
#  ('', '', 0)
#
#  (Synset('liquid.n.01'), Synset('water.n.06'), 0.9230769230769231)
#
#  (Synset('baseball.n.01'), Synset('season.n.01'), 0.11764705882352941)
#
#  (Synset('game.n.01'), Synset('victory.n.01'), 0.5)
#
#  (Synset('game.n.01'), Synset('team.n.02'), 0.18181818181818182)
#
#  (Synset('marathon.n.01'), Synset('dash.n.02'), 0.4444444444444444)
#
#  (Synset('game.n.02'), Synset('series.n.04'), 0.8333333333333334)
#
#  (Synset('game.n.01'), Synset('defeat.n.01'), 0.5)
#
#  (Synset('seven-spot.n.01'), Synset('series.n.05'), 0.2857142857142857)
#
#  (Synset('seafood.n.01'), Synset('sea.n.01'), 0.2222222222222222)
#
#  (Synset('seafood.n.01'), Synset('food.n.02'), 0.8888888888888888)
#
#  (Synset('seafood.n.01'), Synset('lobster.n.01'), 0.8333333333333334)
#
#  (Synset('lobster.n.01'), Synset('food.n.02'), 0.7272727272727273)
#
#  (Synset('lobster.n.01'), Synset('wine.n.01'), 0.25)
#
#  (Synset('food.n.03'), Synset('planning.n.03'), 0.5)
#
#  (Synset('video_recording.n.01'), Synset('archive.n.01'), 0.5)
#
#  (Synset('beginning.n.02'), Synset('year.n.01'), 0.4444444444444444)
#
#  (Synset('start.n.01'), Synset('match.n.02'), 0.5)
#
#  (Synset('game.n.05'), Synset('turn.n.09'), 0.875)
#
#  (Synset('boxing.n.01'), Synset('round_of_golf.n.01'), 0.7)
#
#  (Synset('championship.n.02'), Synset('tournament.n.01'), 0.8333333333333334)
#
#  (Synset('crusade.v.01'), Synset('kill.v.02'), 0.16666666666666666)
#
#  (Synset('credit_line.n.01'), Synset('insurance.n.01'), 0.6666666666666666)
#
#  (Synset('day.n.04'), Synset('summer.n.01'), 0.7272727272727273)
#
#  (Synset('summer.n.01'), Synset('drought.n.02'), 0.7272727272727273)
#
#  (Synset('summer.n.01'), Synset('nature.n.01'), 0.2)
#
#  (Synset('day.n.04'), Synset('dawn.n.03'), 0.8)
#
#  (Synset('nature.n.01'), Synset('environment.n.01'), 0.4444444444444444)
#
#  (Synset('environment.n.01'), Synset('ecology.n.01'), 0.9090909090909091)
#
#  (Synset('nature.n.03'), Synset('man.n.03'), 0.46153846153846156)
#
#  (Synset('man.n.01'), Synset('woman.n.01'), 0.875)
#
#  (Synset('man.n.03'), Synset('governor.n.01'), 0.75)
#
#  (Synset('murder.n.01'), Synset('manslaughter.n.01'), 0.9090909090909091)
#
#  (Synset('soap.n.02'), Synset('opera.n.01'), 0.125)
#
#  (Synset('opera.n.03'), Synset('operation.n.08'), 0.18181818181818182)
#
#  (Synset('biography.n.01'), Synset('moral.n.01'), 0.3333333333333333)
#
#  (Synset('stress.n.03'), Synset('life.n.01'), 0.46153846153846156)
#
#  (Synset('output.n.04'), Synset('crowd.n.02'), 0.2222222222222222)
#
#  (Synset('television.n.01'), Synset('film.n.02'), 0.75)
#
#  (Synset('lover.n.01'), Synset('quarrel.n.02'), 0.3333333333333333)
#
#  (Synset('viewer.n.02'), Synset('series.n.03'), 0.4444444444444444)
#
#  ('', '', 0)
#
#  (Synset('population.n.05'), Synset('development.n.01'), 0.7)
#
#  (Synset('morality.n.01'), Synset('importance.n.01'), 0.6)
#
#  (Synset('morality.n.01'), Synset('marriage.n.04'), 0.4444444444444444)
#
#  (Synset('mexico.n.01'), Synset('brazil.n.01'), 0.7777777777777778)
#
#  (Synset('sex.n.04'), Synset('equality.n.01'), 0.36363636363636365)
#
#  (Synset('change.n.03'), Synset('attitude.n.03'), 0.47058823529411764)
#
#  (Synset('class.n.01'), Synset('planning.n.01'), 0.18181818181818182)
#
#  (Synset('opera.n.01'), Synset('diligence.n.02'), 0.15384615384615385)
#
#  (Synset('boodle.n.01'), Synset('approach.n.05'), 0.15384615384615385)
#
#  (Synset('practice.n.05'), Synset('institution.n.03'), 0.8)
#
#  (Synset('ministry.n.01'), Synset('culture.n.01'), 0.46153846153846156)
#
#  (Synset('problem.n.01'), Synset('challenge.n.01'), 0.5454545454545454)
#
#  (Synset('size.n.04'), Synset('prominence.n.01'), 0.5454545454545454)
#
#  (Synset('area.n.01'), Synset('citizen.n.01'), 0.3076923076923077)
#
#  ('', '', 0)
#
#  (Synset('exploitation.n.01'), Synset('issue.n.04'), 0.7142857142857143)
#
#  (Synset('experience.n.03'), Synset('music.n.03'), 0.5454545454545454)
#
#  (Synset('music.n.03'), Synset('undertaking.n.01'), 0.7692307692307693)
#
#  (Synset('glass.n.01'), Synset('metallic_element.n.01'), 0.4)
#
#  (Synset('aluminum.n.01'), Synset('metallic_element.n.01'), 0.9230769230769231)
#
#  (Synset('opportunity.n.01'), Synset('credibility.n.01'), 0.4)
#
#  (Synset('exhibit.n.01'), Synset('memorabilia.n.01'), 0.3333333333333333)
#
#  ('', '', 0)
#
#  (Synset('rock_'n'_roll.n.01'), Synset('jazz.n.02'), 0.8571428571428571)
#
#  (Synset('museum.n.01'), Synset('theater.n.01'), 0.5714285714285714)
#
#  (Synset('observation.n.01'), Synset('architecture.n.03'), 0.6666666666666666)
#
#  (Synset('quad.n.03'), Synset('universe.n.01'), 0.5)
#
#  (Synset('preservation.n.02'), Synset('worldly_concern.n.01'), 0.5333333333333333)
#
#  (Synset('admission.n.02'), Synset('slate.n.04'), 0.5)
#
#  (Synset('shower.n.03'), Synset('thunderstorm.n.01'), 0.6666666666666666)
#
#  (Synset('shower.n.02'), Synset('flood.n.04'), 0.6)
#
#  ('', '', 0)
#
#  (Synset('catastrophe.n.02'), Synset('sphere.n.01'), 0.42857142857142855)
#
#  (Synset('governor.n.02'), Synset('office.n.01'), 0.47058823529411764)
#
#  (Synset('computer_architecture.n.02'), Synset('century.n.01'), 0.18181818181818182)
